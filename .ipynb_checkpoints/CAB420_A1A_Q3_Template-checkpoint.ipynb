# %% [markdown]
# # CAB420 Assignment 1A Question 3: Template and Utilities Demo
# Simon Denman (s.denman@qut.edu.au)
#
# ## Overview
#
# This notebook provides a quick demo and overview of the provided utility functions to help with Assignment 1A, Question 3.
#
# It also implements the SVM that you are to compare against when responsing to the question.
#
# Please make sure you read the assignment brief on canvas, and check the FAQ for other information.
#
# **Note: File paths used in this template may need to change for your local machine. Please set these based on your local file system structure.**
#
# ## Utility Functions
#
# The following cell contains utility functions to:
# * Load the data
# * Vectorise the data
# * Plot images
# * Resize all images
# * Convert images to grayscale
#
# These are provided to assist you in developing your solution.

# %%
#
# Utility functions for CAB420, Assignment 1A, Q3
# Author: Simon Denman (s.denman@qut.edu.au)
#
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

from scipy.io import loadmat        # to load mat files
import matplotlib.pyplot as plt     # for plotting
import numpy as np                  # for reshaping, array manipulation
import cv2                          # for colour conversion
import tensorflow as tf             # for bulk image resize
import keras

# Load data for Q3
#  train_path: path to training data mat file
#  test_path:  path to testing data mat file
#
#  returns:    arrays for training and testing X and Y data
#
def load_data(train_path, val_path, test_path):

    # load files
    train = loadmat(train_path)
    val = loadmat(val_path)
    test = loadmat(test_path)

    # pull out training set and scale X data
    train_X = train['train_X'] / 255.0
    train_Y = train['train_y'].reshape(-1)

    # pull out validation set and scale X data
    val_X = val['val_X'] / 255.0
    val_Y = val['val_y'].reshape(-1)

    # pull out test set and scale X data
    test_X = test['test_X'] / 255.0
    test_Y = test['test_y'].reshape(-1)

    # return loaded data
    return train_X, train_Y, val_X, val_Y, test_X, test_Y

# vectorise an array of images, such that the shape is changed from {samples, width, height, channels} to
# (samples, width * height * channels)
#   images: array of images to vectorise
#
#   returns: vectorised array of images
#
def vectorise(images):
    # use numpy's reshape to vectorise the data
    return np.reshape(images, [len(images), -1])

# Plot some images and their labels. Will plot the first 100 samples in a 10x10 grid
#  x: array of images, of shape (samples, width, height, channels)
#  y: labels of the images
#
def plot_images(x, y):
    fig = plt.figure(figsize=[15, 18])
    for i in range(100):
        ax = fig.add_subplot(10, 10, i + 1)
        ax.imshow(x[i,:])
        ax.set_title(y[i])
        ax.axis('off')

# Resize an array of images
#  images:   array of images, of shape (samples, width, height, channels)
#  new_size: tuple of the new size, (new_width, new_height)
#
#  returns:  resized array of images, (samples, new_width, new_height, channels)
#
def resize(images, new_size):
    # tensorflow has an image resize funtion that can do this in bulk
    # note the conversion back to numpy after the resize
    return tf.image.resize(images, new_size).numpy()
          
# Convert images to grayscale
#   images:  array of colour images to convert, of size (samples, width, height, 3)
#
#   returns: array of converted images, of size (samples, width, height, 1)
#
def convert_to_grayscale(images):
    # storage for converted images
    gray = []
    # loop through images
    for i in range(len(images)):
        # convert each image using openCV
        gray.append(cv2.cvtColor(images[i,:], cv2.COLOR_BGR2GRAY))
    # pack converted list as an array and return
    return np.expand_dims(np.array(gray), axis = -1)

# %% [markdown]
# ## Utility Function Demonstration
#
# The following presents a brief demonstration of the utility functions. These portions of code do not form part of the template, or solution, and could be commented out/removed.
#
# ### Data Loading
#
# Load the data, and visualise images.

# %%
train_X, train_Y, val_X, val_Y, test_X, test_Y = load_data('Q3/q3_train.mat', 'Q3/q3_validation.mat', 'Q3/q3_test.mat')

# check shape of data
print(train_X.shape)
print(train_Y.shape)
print(val_X.shape)
print(val_Y.shape)
print(test_X.shape)
print(test_Y.shape)

# visualise images as a sanity check
plot_images(train_X, train_Y)
# Out:
# (1000, 32, 32, 3)
# (1000,)
# (1000, 32, 32, 3)
# (1000,)
# (10000, 32, 32, 3)
# (10000,)

# %% [markdown]
# ### Vectorise Data
#
# To train an SVM, each sample needs to be a vector rather than an image.

# %%
train_vector_X = vectorise(train_X)
val_vector_X = vectorise(val_X)
test_vector_X = vectorise(test_X)
print(train_vector_X.shape)
print(val_vector_X.shape)
print(test_vector_X.shape)
# Out:
# (1000, 3072)
# (1000, 3072)
# (10000, 3072)

# %% [markdown]
# ### Conversion and Resizing
#
# You may wish to either:
# * Resize images
# * Convert images to grayscale
#
# Two functions are provided to do this, and can be used in combination as shown below.

# %%
train_X_small = convert_to_grayscale(resize(train_X, (20, 20)))
print(train_X_small.shape)
plot_images(train_X_small, train_Y)
# Out:
# 2026-03-29 08:43:45.271568: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# (1000, 20, 20, 1)

# %% [markdown]
# ### Measuring Time
#
# There are a lot of ways to measure time in python. A simple one is to use ``process_time`` within the ``time`` package. This will simply measure the ellapsed process time in seconds. We can use ths to measure individual parts of our code as follows:

# %%
# import process_time
from time import process_time

# get a start time
time_1 = process_time()

# do some stuff, in this case we'll just load some data
train_X, train_Y,val_X, val_Y, test_X, test_Y = load_data('Q3/q3_train.mat', 'Q3/q3_validation.mat', 'Q3/q3_test.mat')

# get the end time of our first lot of "stuff"
time_2 = process_time()

# do some other stuff
train_X_small = convert_to_grayscale(resize(train_X, (20, 20)))

# get the end time of our first lot of "stuff"
time_3 = process_time()

# the time it took to do "our stuff" is just the difference between the start and end times
print('Time to load data:   %f seconds' % (time_2 - time_1))
print('Time to resize data: %f seconds' % (time_3 - time_2))
# Out:
# Time to load data:   0.053376 seconds
# Time to resize data: 0.016532 seconds

# %% [markdown]
# ## Question 3 Template
#
# The following provides a starting point for your solution. It trains the SVM that you are to compare your trained DCNNs against, and measures the time taken to train this SVM, and to perform inference with the train and test sets.
#
# This does not measure the performance of the SVM - you will need to implement this as part of your solution.

# %%
import numpy as np
from time import process_time
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import random
import pandas as pd

seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# Display settings for confusion matrices
sns.set(style='whitegrid', font_scale=1.0)

# Update paths if needed
train_X, train_Y, val_X, val_Y, test_X, test_Y = load_data('Q3/q3_train.mat',
                                                             'Q3/q3_validation.mat',
                                                             'Q3/q3_test.mat')

print('Shapes:')
print(' train_X', train_X.shape, 'train_Y', train_Y.shape)
print(' val_X', val_X.shape, 'val_Y', val_Y.shape)
print(' test_X', test_X.shape, 'test_Y', test_Y.shape)

num_classes = len(np.unique(train_Y))
input_shape = train_X.shape[1:]
print('num_classes', num_classes, 'input_shape', input_shape)
# Out:
# Shapes:
#  train_X (1000, 32, 32, 3) train_Y (1000,)
#  val_X (1000, 32, 32, 3) val_Y (1000,)
#  test_X (10000, 32, 32, 3) test_Y (10000,)
# num_classes 10 input_shape (32, 32, 3)

# %%
from sklearn.svm import SVC
from time import process_time

# load data
train_X, train_Y,val_X, val_Y, test_X, test_Y = load_data('Q3/q3_train.mat', 'Q3/q3_validation.mat', 'Q3/q3_test.mat')

# any resize, colour change, etc, would go here
# if you do anything, do the same thing to the training, validation, and test sets

# vectorise data
# If you do any resize, reshape, etc of the data prior to putting this into your DCNN, change this code to 
# vectorise that verison of the data. The same data should be used by all models for a fair comparison; though
# you will only vectorise the data for the SVM (i.e. the DCNN will get the data as images).
train_vector_X = vectorise(train_X)
val_vector_X = vectorise(val_X)
test_vector_X = vectorise(test_X)

# train the SVM
# Note that you are not required to tune the SVM, just use it as it is. This also means that we do not need the validation
# set for the SVM as we're not selecting hyper-parameters
# measure the start time of training
svm_train_start = process_time()
# run the training - note that you don't need to change any parameters here except potentially for the input data is you 
# resize, change colour, etc
svm = SVC(C = 1.0, kernel = 'linear').fit(train_vector_X, train_Y)
# record the end time of the training
svm_train_end = process_time()
# predict on the training set
train_predictions = svm.predict(train_vector_X)
# measure of the time of the training set prediction
svm_train_pred_end = process_time()
# predict on the test set
test_predictions = svm.predict(test_vector_X)
# measure the end time on the prediction of the test set
svm_test_pred_end = process_time()

# check how long the SVM took to train
svm_train_time = svm_train_end - svm_train_start
# check how long the SVM took to perform inference on the training set
svm_inference_train_time = svm_train_pred_end - svm_train_end
# check how long the SVM took to perform inference on the testing set
svm_inference_test_time = svm_test_pred_end - svm_train_pred_end
# print some times
print('Training Time: %f\nInference Time (training set): %f\nInference Time (testing set): %f' % \
      (svm_train_time, svm_inference_train_time, svm_inference_test_time))

# evaluate SVM
# here you can insert whatever evaluation metrics you feel are appropriate, though F1 and a confusion matrix would be a fair
# option

# Vectorise
train_vector_X = vectorise(train_X)
val_vector_X = vectorise(val_X)
test_vector_X = vectorise(test_X)

# Train SVM and measure times
svm_train_start = process_time()
svm = SVC(C=1.0, kernel='linear', random_state=seed).fit(train_vector_X, train_Y)
svm_train_end = process_time()

# Inference timing (train)
svm_train_pred_start = process_time()
train_pred_svm = svm.predict(train_vector_X)
svm_train_pred_end = process_time()

# Inference timing (test)
svm_test_pred_start = process_time()
test_pred_svm = svm.predict(test_vector_X)
svm_test_pred_end = process_time()

# Timings
svm_train_time = svm_train_end - svm_train_start
svm_inference_train_time = svm_train_pred_end - svm_train_pred_start
svm_inference_test_time = svm_test_pred_end - svm_test_pred_start

# Metrics
svm_train_acc = accuracy_score(train_Y, train_pred_svm)
svm_test_acc = accuracy_score(test_Y, test_pred_svm)
svm_test_f1 = f1_score(test_Y, test_pred_svm, average='macro')

print('SVM Training Time: %.4f s' % svm_train_time)
print('SVM Inference Time (train): %.4f s' % svm_inference_train_time)
print('SVM Inference Time (test): %.4f s' % svm_inference_test_time)
print('SVM Train Acc: %.4f  Test Acc: %.4f  Test F1 (macro): %.4f' %
      (svm_train_acc, svm_test_acc, svm_test_f1))

# Confusion matrix (test)
cm = confusion_matrix(test_Y, test_pred_svm)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('SVM Confusion Matrix (test)')
plt.xlabel('Predicted'); plt.ylabel('True')
plt.show()
# Out:
# Training Time: 1.739067
# Inference Time (training set): 0.533641
# Inference Time (testing set): 5.303772
# SVM Training Time: 1.6828 s
# SVM Inference Time (train): 0.5395 s
# SVM Inference Time (test): 5.5511 s
# SVM Train Acc: 0.8130  Test Acc: 0.1861  Test F1 (macro): 0.1409

# %%
# develop, evaluate and compare DCNNs
#
# You should create one DCNN which you will train from scratch, and then add augmentation to this and train it again.
# Use whatever augmentation you feel is appropraite.
#
# For your DCNN design, feel free to borrow networks from pracs and lecture examples. The network does not need to be
# overly complex, but you should briefly explain your selection of this model. You should avoid networks so simple 
# that they perform very badly. Look at the lecture notes and the sort of simple DCNNs we've created as a guide. With 
# respect to training time, there is no minimum or maximum training time, but you should either:
#  - Train both your models to convergence, noting that this may take different numbers of epochs
#  - Train your networks for the same period of time, ensuring that this time is sufficient for at least one to converge
# Keep in mind that with the very small training set, you may need to increase the number of epochs compared to what we
# see in the lecture examples

def build_resnet_like(input_shape, num_classes, filters=[32,64], blocks_per_stage=2):
    """
    Simple ResNet-like model suitable for small images.
    - filters: list of filter sizes for each stage
    - blocks_per_stage: number of residual blocks per stage
    """
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(filters[0], (3,3), padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)

    def residual_block(x, filters):
        shortcut = x
        x = layers.Conv2D(filters, (3,3), padding='same', activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Conv2D(filters, (3,3), padding='same', activation=None)(x)
        x = layers.BatchNormalization()(x)
        # match channels if needed
        if shortcut.shape[-1] != filters:
            shortcut = layers.Conv2D(filters, (1,1), padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)
        x = layers.Add()([x, shortcut])
        x = layers.Activation('relu')(x)
        return x

    for f in filters:
        for _ in range(blocks_per_stage):
            x = residual_block(x, f)
        x = layers.MaxPooling2D((2,2))(x)
        x = layers.Dropout(0.2)(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=inputs, outputs=outputs, name='resnet_like_small')
    model.compile(optimizer=optimizers.Adam(1e-3),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def build_vgg_like(input_shape, num_classes, conv_filters=[32,64,128], dense_units=256):
    """
    Simple VGG-like model:
    - conv_filters: list of filters per stage
    """
    inputs = layers.Input(shape=input_shape)
    x = inputs
    for f in conv_filters:
        x = layers.Conv2D(f, (3,3), padding='same', activation='relu')(x)
        x = layers.Conv2D(f, (3,3), padding='same', activation='relu')(x)
        x = layers.MaxPooling2D((2,2))(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(dense_units, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=inputs, outputs=outputs, name='vgg_like_small')
    model.compile(optimizer=optimizers.Adam(1e-3),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

def train_and_evaluate_model(model,
                             train_X, train_Y,
                             val_X, val_Y,
                             test_X, test_Y,
                             use_augmentation=False,
                             datagen=None,
                             batch_size=64,
                             epochs=50,
                             verbose=2):
    """
    Trains model (with or without augmentation), measures training time,
    measures inference time on train and test, returns metrics and timings.
    """
    es = callbacks.EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)

    # Train
    if use_augmentation:
        assert datagen is not None, "datagen required for augmentation"
        train_gen = datagen.flow(train_X, train_Y, batch_size=batch_size, shuffle=True)
        steps_per_epoch = int(np.ceil(len(train_X) / batch_size))
        t0 = process_time()
        history = model.fit(train_gen,
                            steps_per_epoch=steps_per_epoch,
                            epochs=epochs,
                            validation_data=(val_X, val_Y),
                            callbacks=[es],
                            verbose=verbose)
        t1 = process_time()
    else:
        t0 = process_time()
        history = model.fit(train_X, train_Y,
                            batch_size=batch_size,
                            epochs=epochs,
                            validation_data=(val_X, val_Y),
                            callbacks=[es],
                            verbose=verbose)
        t1 = process_time()

    train_time = t1 - t0

    # Inference on train
    t2 = process_time()
    train_pred = np.argmax(model.predict(train_X, batch_size=128), axis=1)
    t3 = process_time()
    inference_train_time = t3 - t2

    # Inference on test
    t4 = process_time()
    test_pred = np.argmax(model.predict(test_X, batch_size=128), axis=1)
    t5 = process_time()
    inference_test_time = t5 - t4

    # Metrics
    train_acc = accuracy_score(train_Y, train_pred)
    test_acc = accuracy_score(test_Y, test_pred)
    test_f1 = f1_score(test_Y, test_pred, average='macro')
    cm = confusion_matrix(test_Y, test_pred)

    results = {
        'history': history,
        'train_time': train_time,
        'inference_train_time': inference_train_time,
        'inference_test_time': inference_test_time,
        'train_acc': train_acc,
        'test_acc': test_acc,
        'test_f1': test_f1,
        'confusion_matrix': cm,
        'predictions_test': test_pred
    }
    return results

datagen = ImageDataGenerator(
    rotation_range=12,
    width_shift_range=0.10,
    height_shift_range=0.10,
    horizontal_flip=True,
    zoom_range=0.08
)
datagen.fit(train_X)

batch_size = 64
epochs = 50

# 1) ResNet-like (no augmentation)
resnet_model = build_resnet_like(input_shape, num_classes, filters=[32,64], blocks_per_stage=1)
resnet_results = train_and_evaluate_model(resnet_model,
                                          train_X, train_Y, val_X, val_Y, test_X, test_Y,
                                          use_augmentation=False,
                                          datagen=None,
                                          batch_size=batch_size,
                                          epochs=epochs,
                                          verbose=2)

# Plot confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(resnet_results['confusion_matrix'], annot=True, fmt='d', cmap='Greens')
plt.title('ResNet-like (no aug) Confusion Matrix (test)')
plt.xlabel('Predicted'); plt.ylabel('True')
plt.show()

# 2) ResNet-like (with augmentation)
resnet_model_aug = build_resnet_like(input_shape, num_classes, filters=[32,64], blocks_per_stage=1)
resnet_results_aug = train_and_evaluate_model(resnet_model_aug,
                                              train_X, train_Y, val_X, val_Y, test_X, test_Y,
                                              use_augmentation=True,
                                              datagen=datagen,
                                              batch_size=batch_size,
                                              epochs=epochs,
                                              verbose=2)

plt.figure(figsize=(8,6))
sns.heatmap(resnet_results_aug['confusion_matrix'], annot=True, fmt='d', cmap='Oranges')
plt.title('ResNet-like (with aug) Confusion Matrix (test)')
plt.xlabel('Predicted'); plt.ylabel('True')
plt.show()

# 3) VGG-like (no augmentation)
vgg_model = build_vgg_like(input_shape, num_classes, conv_filters=[32,64], dense_units=256)
vgg_results = train_and_evaluate_model(vgg_model,
                                       train_X, train_Y, val_X, val_Y, test_X, test_Y,
                                       use_augmentation=False,
                                       datagen=None,
                                       batch_size=batch_size,
                                       epochs=epochs,
                                       verbose=2)

plt.figure(figsize=(8,6))
sns.heatmap(vgg_results['confusion_matrix'], annot=True, fmt='d', cmap='Blues')
plt.title('VGG-like (no aug) Confusion Matrix (test)')
plt.xlabel('Predicted'); plt.ylabel('True')
plt.show()

# 4) VGG-like (with augmentation)
vgg_model_aug = build_vgg_like(input_shape, num_classes, conv_filters=[32,64], dense_units=256)
vgg_results_aug = train_and_evaluate_model(vgg_model_aug,
                                           train_X, train_Y, val_X, val_Y, test_X, test_Y,
                                           use_augmentation=True,
                                           datagen=datagen,
                                           batch_size=batch_size,
                                           epochs=epochs,
                                           verbose=2)

plt.figure(figsize=(8,6))
sns.heatmap(vgg_results_aug['confusion_matrix'], annot=True, fmt='d', cmap='Purples')
plt.title('VGG-like (with aug) Confusion Matrix (test)')
plt.xlabel('Predicted'); plt.ylabel('True')
plt.show()
# Out:
# Epoch 1/50
# 16/16 - 4s - 266ms/step - accuracy: 0.1240 - loss: 2.8070 - val_accuracy: 0.1440 - val_loss: 2.2897
# Epoch 2/50
# 16/16 - 2s - 96ms/step - accuracy: 0.1350 - loss: 2.5261 - val_accuracy: 0.1710 - val_loss: 2.2664
# Epoch 3/50
# 16/16 - 2s - 97ms/step - accuracy: 0.1710 - loss: 2.4409 - val_accuracy: 0.1800 - val_loss: 2.2555
# Epoch 4/50
# 16/16 - 2s - 96ms/step - accuracy: 0.1850 - loss: 2.3617 - val_accuracy: 0.1580 - val_loss: 2.2548
# Epoch 5/50
# 16/16 - 2s - 95ms/step - accuracy: 0.2190 - loss: 2.3498 - val_accuracy: 0.1380 - val_loss: 2.2507
# Epoch 6/50
# 16/16 - 1s - 91ms/step - accuracy: 0.2370 - loss: 2.2364 - val_accuracy: 0.1920 - val_loss: 2.2454
# Epoch 7/50
# 16/16 - 1s - 91ms/step - accuracy: 0.2470 - loss: 2.2255 - val_accuracy: 0.1990 - val_loss: 2.2453
# Epoch 8/50
# 16/16 - 1s - 82ms/step - accuracy: 0.2760 - loss: 2.1412 - val_accuracy: 0.1930 - val_loss: 2.2411
# Epoch 9/50
# 16/16 - 2s - 96ms/step - accuracy: 0.2860 - loss: 2.0975 - val_accuracy: 0.1930 - val_loss: 2.2642
# Epoch 10/50
# 16/16 - 1s - 92ms/step - accuracy: 0.2930 - loss: 2.0753 - val_accuracy: 0.1930 - val_loss: 2.2460
# Epoch 11/50
# 16/16 - 1s - 82ms/step - accuracy: 0.3020 - loss: 2.0330 - val_accuracy: 0.1980 - val_loss: 2.2476
# Epoch 12/50
# 16/16 - 2s - 95ms/step - accuracy: 0.3520 - loss: 1.9499 - val_accuracy: 0.1930 - val_loss: 2.2803
# Epoch 13/50
# 16/16 - 1s - 93ms/step - accuracy: 0.3740 - loss: 1.9036 - val_accuracy: 0.1930 - val_loss: 2.4176
# Epoch 14/50
# 16/16 - 1s - 92ms/step - accuracy: 0.3910 - loss: 1.8157 - val_accuracy: 0.1930 - val_loss: 2.5626
# Epoch 15/50
# 16/16 - 2s - 94ms/step - accuracy: 0.3820 - loss: 1.7929 - val_accuracy: 0.1930 - val_loss: 2.6630
# Epoch 16/50
# 16/16 - 2s - 95ms/step - accuracy: 0.3890 - loss: 1.7453 - val_accuracy: 0.1930 - val_loss: 2.7085
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# Epoch 1/50
# 16/16 - 5s - 284ms/step - accuracy: 0.1000 - loss: 2.8229 - val_accuracy: 0.0990 - val_loss: 2.2974
# Epoch 2/50
# 16/16 - 2s - 97ms/step - accuracy: 0.1260 - loss: 2.6202 - val_accuracy: 0.1250 - val_loss: 2.2885
# Epoch 3/50
# 16/16 - 2s - 98ms/step - accuracy: 0.1380 - loss: 2.5779 - val_accuracy: 0.1420 - val_loss: 2.2879
# Epoch 4/50
# 16/16 - 2s - 99ms/step - accuracy: 0.1640 - loss: 2.4572 - val_accuracy: 0.1380 - val_loss: 2.2743
# Epoch 5/50
# 16/16 - 2s - 99ms/step - accuracy: 0.1540 - loss: 2.4916 - val_accuracy: 0.1400 - val_loss: 2.2576
# Epoch 6/50
# 16/16 - 2s - 100ms/step - accuracy: 0.1970 - loss: 2.4019 - val_accuracy: 0.1460 - val_loss: 2.2544
# Epoch 7/50
# 16/16 - 2s - 100ms/step - accuracy: 0.2200 - loss: 2.3873 - val_accuracy: 0.1390 - val_loss: 2.2507
# Epoch 8/50
# 16/16 - 2s - 100ms/step - accuracy: 0.2290 - loss: 2.3406 - val_accuracy: 0.1700 - val_loss: 2.2502
# Epoch 9/50
# 16/16 - 2s - 99ms/step - accuracy: 0.2220 - loss: 2.2986 - val_accuracy: 0.2140 - val_loss: 2.2502
# Epoch 10/50
# 16/16 - 2s - 99ms/step - accuracy: 0.2320 - loss: 2.3072 - val_accuracy: 0.2140 - val_loss: 2.2430
# Epoch 11/50
# 16/16 - 2s - 100ms/step - accuracy: 0.2610 - loss: 2.2466 - val_accuracy: 0.2160 - val_loss: 2.2377
# Epoch 12/50
# 16/16 - 2s - 100ms/step - accuracy: 0.2570 - loss: 2.2628 - val_accuracy: 0.2270 - val_loss: 2.2429
# Epoch 13/50
# 16/16 - 2s - 99ms/step - accuracy: 0.2500 - loss: 2.2091 - val_accuracy: 0.2150 - val_loss: 2.2446
# Epoch 14/50
# 16/16 - 2s - 99ms/step - accuracy: 0.2830 - loss: 2.1469 - val_accuracy: 0.2200 - val_loss: 2.2371
# Epoch 15/50
# 16/16 - 2s - 99ms/step - accuracy: 0.2680 - loss: 2.1250 - val_accuracy: 0.1620 - val_loss: 2.2418
# Epoch 16/50
# 16/16 - 2s - 99ms/step - accuracy: 0.2820 - loss: 2.0909 - val_accuracy: 0.1860 - val_loss: 2.2426
# Epoch 17/50
# 16/16 - 2s - 100ms/step - accuracy: 0.2980 - loss: 2.0779 - val_accuracy: 0.2410 - val_loss: 2.2275
# Epoch 18/50
# 16/16 - 2s - 99ms/step - accuracy: 0.3100 - loss: 2.0219 - val_accuracy: 0.2340 - val_loss: 2.1981
# Epoch 19/50
# 16/16 - 2s - 98ms/step - accuracy: 0.2790 - loss: 2.0709 - val_accuracy: 0.2630 - val_loss: 2.2166
# Epoch 20/50
# 16/16 - 2s - 99ms/step - accuracy: 0.3010 - loss: 1.9836 - val_accuracy: 0.2370 - val_loss: 2.1806
# Epoch 21/50
# 16/16 - 2s - 100ms/step - accuracy: 0.3230 - loss: 1.9760 - val_accuracy: 0.1680 - val_loss: 2.3590
# Epoch 22/50
# 16/16 - 2s - 99ms/step - accuracy: 0.3210 - loss: 1.9387 - val_accuracy: 0.1830 - val_loss: 2.2685
# Epoch 23/50
# 16/16 - 2s - 98ms/step - accuracy: 0.3390 - loss: 1.8975 - val_accuracy: 0.1800 - val_loss: 2.3594
# Epoch 24/50
# 16/16 - 2s - 101ms/step - accuracy: 0.3430 - loss: 1.8806 - val_accuracy: 0.1380 - val_loss: 2.4451
# 16/16 - 1s - 56ms/step - accuracy: 0.7250 - loss: 0.8215 - val_accuracy: 0.5900 - val_loss: 1.3103
# Epoch 48/50
# 16/16 - 1s - 57ms/step - accuracy: 0.7280 - loss: 0.7999 - val_accuracy: 0.6610 - val_loss: 1.0536
# Epoch 49/50
# 16/16 - 1s - 57ms/step - accuracy: 0.7250 - loss: 0.8218 - val_accuracy: 0.6990 - val_loss: 0.9494
# Epoch 50/50
# 16/16 - 1s - 57ms/step - accuracy: 0.7390 - loss: 0.7827 - val_accuracy: 0.7270 - val_loss: 0.8784
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step

# %%
rows = []

# SVM row
rows.append({
    'model': 'SVM (linear)',
    'train_time_s': svm_train_time,
    'inf_train_s': svm_inference_train_time,
    'inf_test_s': svm_inference_test_time,
    'train_acc': svm_train_acc,
    'test_acc': svm_test_acc,
    'test_f1_macro': svm_test_f1
})

# ResNet no aug
rows.append({
    'model': 'ResNet-like (no aug)',
    'train_time_s': resnet_results['train_time'],
    'inf_train_s': resnet_results['inference_train_time'],
    'inf_test_s': resnet_results['inference_test_time'],
    'train_acc': resnet_results['train_acc'],
    'test_acc': resnet_results['test_acc'],
    'test_f1_macro': resnet_results['test_f1']
})

# ResNet with aug
rows.append({
    'model': 'ResNet-like (with aug)',
    'train_time_s': resnet_results_aug['train_time'],
    'inf_train_s': resnet_results_aug['inference_train_time'],
    'inf_test_s': resnet_results_aug['inference_test_time'],
    'train_acc': resnet_results_aug['train_acc'],
    'test_acc': resnet_results_aug['test_acc'],
    'test_f1_macro': resnet_results_aug['test_f1']
})

# VGG no aug
rows.append({
    'model': 'VGG-like (no aug)',
    'train_time_s': vgg_results['train_time'],
    'inf_train_s': vgg_results['inference_train_time'],
    'inf_test_s': vgg_results['inference_test_time'],
    'train_acc': vgg_results['train_acc'],
    'test_acc': vgg_results['test_acc'],
    'test_f1_macro': vgg_results['test_f1']
})

# VGG with aug
rows.append({
    'model': 'VGG-like (with aug)',
    'train_time_s': vgg_results_aug['train_time'],
    'inf_train_s': vgg_results_aug['inference_train_time'],
    'inf_test_s': vgg_results_aug['inference_test_time'],
    'train_acc': vgg_results_aug['train_acc'],
    'test_acc': vgg_results_aug['test_acc'],
    'test_f1_macro': vgg_results_aug['test_f1']
})

df_summary = pd.DataFrame(rows)
# reorder columns for readability
df_summary = df_summary[['model','train_time_s','inf_train_s','inf_test_s','train_acc','test_acc','test_f1_macro']]
print(df_summary.to_string(index=False))

# %%
# For your write-up, you should include:
# - briefly mention any pre-processing you did and why
# - outline your network design, and training approach. The discussion of training should note how long the model was trained
#   for, and if it converged. If you observe the non-augmented and augmented networks training at different rates, discuss that
#   here
# - outline your data augmentation, and briefly justify why these methods were chosen.
# - an evaluation and comparison of three models, which should highlight any differences observed between the models, and the
#   inference time of the three models
# Your write-up should be supported by appropriate figures and tables. Figures and tables should have numbers and meaningful captions.
# Note that figures and tables are not included in the page limits.
#
# SEE THE ASSIGNMENT BRIEF ON CANVAS FOR MORE DETAILS AND NOTE THAT A NOTEBOOK FILE DOES NOT CONSTITUTE A VALID SUBMISSION. 
# YOU SHOULD WRITE UP YOUR RESPONSE IN A SEPARATE DOCUMENT
